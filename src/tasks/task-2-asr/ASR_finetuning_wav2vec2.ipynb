# %%
# %%capture
# !pip install datasets==1.18.3 transformers==4.17.0 jiwer

# %%
from datasets import load_dataset, load_metric

timit = load_dataset("timit_asr")
# Out:
# Downloading:   0%|          | 0.00/2.40k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# Downloading and preparing dataset timit_asr/clean (download: 828.75 MiB, generated: 7.90 MiB, post-processed: Unknown size, total: 836.65 MiB) to /root/.cache/huggingface/datasets/timit_asr/clean/2.0.1/b11b576ddcccbcefa7c9f0c4e6c2a43756f3033adffe0fb686aa61043d0450ad...
# Downloading:   0%|          | 0.00/869M [00:00<?, ?B/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset timit_asr downloaded and prepared to /root/.cache/huggingface/datasets/timit_asr/clean/2.0.1/b11b576ddcccbcefa7c9f0c4e6c2a43756f3033adffe0fb686aa61043d0450ad. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
timit
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'audio', 'text', 'phonetic_detail', 'word_detail', 'dialect_region', 'sentence_type', 'speaker_id', 'id'],
#         num_rows: 4620
#     })
#     test: Dataset({
#         features: ['file', 'audio', 'text', 'phonetic_detail', 'word_detail', 'dialect_region', 'sentence_type', 'speaker_id', 'id'],
#         num_rows: 1680
#     })
# })

# %%
timit = timit.remove_columns(["phonetic_detail", "word_detail", "dialect_region", "id", "sentence_type", "speaker_id"])

# %%
from datasets import ClassLabel
import random
import pandas as pd
from IPython.display import display, HTML

def show_random_elements(dataset, num_examples=10):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)
    
    df = pd.DataFrame(dataset[picks])
    display(HTML(df.to_html()))

# %%
show_random_elements(timit["train"].remove_columns(["audio", "file"]), num_examples=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A slug had torn half of his stirrup-guard away.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>They are both trend-following methods.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>May I order a strawberry sundae after I eat dinner?</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Tim takes Sheila to see movies twice a week.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Her classical performance gained critical acclaim.</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>But in every period it has been humanism.</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Don't ask me to carry an oily rag like that.</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Don't ask me to carry an oily rag like that.</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>None should ask less.</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>How on earth do you manage it?</td>
#     </tr>
#   </tbody>
# </table>

# %%
import re
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"]'

def remove_special_characters(batch):
    batch["text"] = re.sub(chars_to_ignore_regex, '', batch["text"]).lower() + " "
    return batch

# %%
timit = timit.map(remove_special_characters)
# Out:
# WARNING:datasets.fingerprint:Parameter 'function'=<function remove_special_characters at 0x7fee6c3fc050> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]

# %%
show_random_elements(timit["train"].remove_columns(["audio", "file"]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>nothing is as offensive as innocence</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>curiosity and mediocrity seldom coexist</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>we apply auditory modeling to computer speech recognition</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>don't ask me to carry an oily rag like that</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>i'm going to search this house</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>don't ask me to carry an oily rag like that</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>regular attendance is seldom required</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>correct execution of my instructions is crucial</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>irish youngsters eat fresh kippers for breakfast</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>are holiday aprons available to us</td>
#     </tr>
#   </tbody>
# </table>

# %%
def extract_all_chars(batch):
  all_text = " ".join(batch["text"])
  vocab = list(set(all_text))
  return {"vocab": [vocab], "all_text": [all_text]}

# %%
vocabs = timit.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=timit.column_names["train"])
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
vocab_list = list(set(vocabs["train"]["vocab"][0]) | set(vocabs["test"]["vocab"][0]))

# %%
vocab_dict = {v: k for k, v in enumerate(vocab_list)}
vocab_dict
# Out:
# {'a': 0,
#  "'": 1,
#  ' ': 2,
#  'b': 3,
#  'v': 4,
#  'l': 5,
#  'y': 6,
#  'h': 7,
#  'r': 8,
#  'e': 9,
#  'n': 10,
#  'p': 11,
#  'w': 12,
#  'j': 13,
#  'd': 14,
#  'u': 15,
#  'q': 16,
#  's': 17,
#  'i': 18,
#  'm': 19,
#  'f': 20,
#  'c': 21,
#  'o': 22,
#  'x': 23,
#  'z': 24,
#  'g': 25,
#  't': 26,
#  'k': 27}

# %%
vocab_dict["|"] = vocab_dict[" "]
del vocab_dict[" "]

# %%
vocab_dict["[UNK]"] = len(vocab_dict)
vocab_dict["[PAD]"] = len(vocab_dict)
len(vocab_dict)
# Out:
# 30

# %%
import json
with open('vocab.json', 'w') as vocab_file:
    json.dump(vocab_dict, vocab_file)

# %%
from transformers import Wav2Vec2CTCTokenizer, Wav2Vec2FeatureExtractor, Wav2Vec2Processor

tokenizer = Wav2Vec2CTCTokenizer("./vocab.json", unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|")
feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=False)
processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

# %%
timit["train"][0]["audio"]
# Out:
# {'path': '/root/.cache/huggingface/datasets/downloads/extracted/404950a46da14eac65eb4e2a8317b1372fb3971d980d91d5d5b221275b1fd7e0/data/TRAIN/DR4/MMDM0/SI681.WAV',
#  'array': array([-2.1362305e-04,  6.1035156e-05,  3.0517578e-05, ...,
#         -3.0517578e-05, -9.1552734e-05, -6.1035156e-05], dtype=float32),
#  'sampling_rate': 16000}

# %%
import IPython.display as ipd
import numpy as np
import random

rand_int = random.randint(0, len(timit["train"]))

print(timit["train"][rand_int]["text"])
ipd.Audio(data=np.asarray(timit["train"][rand_int]["audio"]["array"]), autoplay=True, rate=16000)
# Out:
# the wrinkled mouth laughed revealing astonishingly strong white teeth
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
rand_int = random.randint(0, len(timit["train"]))

print("Target text:", timit["train"][rand_int]["text"])
print("Input array shape:", np.asarray(timit["train"][rand_int]["audio"]["array"]).shape)
print("Sampling rate:", timit["train"][rand_int]["audio"]["sampling_rate"])
# Out:
# Target text: don't ask me to carry an oily rag like that
# Input array shape: (57447,)
# Sampling rate: 16000

# %%
def prepare_dataset(batch):
    audio = batch["audio"]

    # batched output is "un-batched" to ensure mapping is correct
    batch["input_values"] = processor(audio["array"], sampling_rate=audio["sampling_rate"]).input_values[0]
    batch["input_length"] = len(batch["input_values"])
    
    with processor.as_target_processor():
        batch["labels"] = processor(batch["text"]).input_ids
    return batch

# %%
timit = timit.map(prepare_dataset, remove_columns=timit.column_names["train"], num_proc=4)

# %%
max_input_length_in_sec = 4.0
timit["train"] = timit["train"].filter(lambda x: x < max_input_length_in_sec * processor.feature_extractor.sampling_rate, input_columns=["input_length"])
# Out:
#   0%|          | 0/5 [00:00<?, ?ba/s]

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %%
wer_metric = load_metric("wer")
# Out:
# Downloading:   0%|          | 0.00/1.90k [00:00<?, ?B/s]

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
from transformers import Wav2Vec2ForCTC

model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-base",
    ctc_loss_reduction="mean", 
    pad_token_id=processor.tokenizer.pad_token_id,
)
# Out:
# Downloading:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/configuration_utils.py:357: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   "Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 "
# Downloading:   0%|          | 0.00/363M [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/wav2vec2-base were not used when initializing Wav2Vec2ForCTC: ['project_hid.weight', 'project_q.bias', 'quantizer.codevectors', 'project_hid.bias', 'quantizer.weight_proj.bias', 'quantizer.weight_proj.weight', 'project_q.weight']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base and are newly initialized: ['lm_head.weight', 'lm_head.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.freeze_feature_encoder()

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
  output_dir="abc",
  group_by_length=True,
  per_device_train_batch_size=8,
  evaluation_strategy="steps",
  num_train_epochs=30,
  fp16=True,
  gradient_checkpointing=True,
  save_steps=500,
  eval_steps=500,
  logging_steps=500,
  learning_rate=1e-4,
  weight_decay=0.005,
  warmup_steps=1000,
  save_total_limit=2,
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=timit["train"],
    eval_dataset=timit["test"],
    tokenizer=processor.feature_extractor,

)
# Out:
# Using amp half precision backend

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 3978
#   Num Epochs = 30
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 14940
#     <div>
#
#       <progress value='14940' max='14940' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14940/14940 1:53:36, Epoch 30/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>3.586800</td>
#       <td>1.750717</td>
#       <td>0.983530</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.852200</td>
#       <td>0.644288</td>
#       <td>0.576942</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.430900</td>
#       <td>0.422041</td>
#       <td>0.455103</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.303500</td>
#       <td>0.419379</td>
#       <td>0.417063</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.232600</td>
#       <td>0.429331</td>
#       <td>0.408862</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.188000</td>
#       <td>0.433618</td>
#       <td>0.384329</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.153600</td>
#       <td>0.444419</td>
#       <td>0.382813</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.146800</td>
#       <td>0.432657</td>
#       <td>0.378609</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.123000</td>
#       <td>0.423748</td>
#       <td>0.375164</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.108800</td>
#       <td>0.456125</td>
#       <td>0.374268</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.099900</td>
#       <td>0.462265</td>
#       <td>0.365723</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.087200</td>
#       <td>0.479556</td>
#       <td>0.364275</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.080100</td>
#       <td>0.540605</td>
#       <td>0.365929</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.071300</td>
#       <td>0.532457</td>
#       <td>0.362897</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.065700</td>
#       <td>0.483103</td>
#       <td>0.366136</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.058600</td>
#       <td>0.521115</td>
#       <td>0.362553</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.054700</td>
#       <td>0.521590</td>
#       <td>0.357935</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.054300</td>
#       <td>0.497733</td>
#       <td>0.364551</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.048500</td>
#       <td>0.508778</td>
#       <td>0.357798</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.042100</td>
#       <td>0.511522</td>
#       <td>0.358556</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.040700</td>
#       <td>0.505992</td>
#       <td>0.354972</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.037200</td>
#       <td>0.469154</td>
#       <td>0.352216</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.031500</td>
#       <td>0.507037</td>
#       <td>0.354076</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.033900</td>
#       <td>0.565857</td>
#       <td>0.353180</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.029200</td>
#       <td>0.496832</td>
#       <td>0.346289</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.025500</td>
#       <td>0.498309</td>
#       <td>0.347185</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.022800</td>
#       <td>0.535457</td>
#       <td>0.343050</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.022800</td>
#       <td>0.528772</td>
#       <td>0.341947</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.022500</td>
#       <td>0.526007</td>
#       <td>0.341947</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-500
# Configuration saved in abc/checkpoint-500/config.json
# Model weights saved in abc/checkpoint-500/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-500/preprocessor_config.json
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-1000
# Configuration saved in abc/checkpoint-1000/config.json
# Model weights saved in abc/checkpoint-1000/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-1000/preprocessor_config.json
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-1500
# Configuration saved in abc/checkpoint-1500/config.json
# Model weights saved in abc/checkpoint-1500/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-1500/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-2000
# Configuration saved in abc/checkpoint-2000/config.json
# Model weights saved in abc/checkpoint-2000/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-2000/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-1000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-2500
# Configuration saved in abc/checkpoint-2500/config.json
# Model weights saved in abc/checkpoint-2500/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-2500/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-1500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-3000
# Configuration saved in abc/checkpoint-3000/config.json
# Model weights saved in abc/checkpoint-3000/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-3000/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-2000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-3500
# Configuration saved in abc/checkpoint-3500/config.json
# Model weights saved in abc/checkpoint-3500/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-3500/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-2500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-4000
# Configuration saved in abc/checkpoint-4000/config.json
# Model weights saved in abc/checkpoint-4000/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-4000/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-3000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-4500
# Configuration saved in abc/checkpoint-4500/config.json
# Model weights saved in abc/checkpoint-4500/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-4500/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-3500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-5000
# Configuration saved in abc/checkpoint-5000/config.json
# Model weights saved in abc/checkpoint-5000/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-5000/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-4000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-5500
# Configuration saved in abc/checkpoint-5500/config.json
# Model weights saved in abc/checkpoint-5500/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-5500/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-4500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-6000
# Configuration saved in abc/checkpoint-6000/config.json
# Model weights saved in abc/checkpoint-6000/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-6000/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-5000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-6500
# Configuration saved in abc/checkpoint-6500/config.json
# Model weights saved in abc/checkpoint-6500/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-6500/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-5500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-7000
# Configuration saved in abc/checkpoint-7000/config.json
# Model weights saved in abc/checkpoint-7000/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-7000/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-6000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-7500
# Configuration saved in abc/checkpoint-7500/config.json
# Model weights saved in abc/checkpoint-7500/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-7500/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-6500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-8000
# Configuration saved in abc/checkpoint-8000/config.json
# Model weights saved in abc/checkpoint-8000/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-8000/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-7000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-8500
# Configuration saved in abc/checkpoint-8500/config.json
# Model weights saved in abc/checkpoint-8500/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-8500/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-7500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-9000
# Configuration saved in abc/checkpoint-9000/config.json
# Model weights saved in abc/checkpoint-9000/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-9000/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-8000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-9500
# Configuration saved in abc/checkpoint-9500/config.json
# Model weights saved in abc/checkpoint-9500/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-9500/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-8500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-10000
# Configuration saved in abc/checkpoint-10000/config.json
# Model weights saved in abc/checkpoint-10000/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-10000/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-9000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-10500
# Configuration saved in abc/checkpoint-10500/config.json
# Model weights saved in abc/checkpoint-10500/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-10500/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-9500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-11000
# Configuration saved in abc/checkpoint-11000/config.json
# Model weights saved in abc/checkpoint-11000/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-11000/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-10000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-11500
# Configuration saved in abc/checkpoint-11500/config.json
# Model weights saved in abc/checkpoint-11500/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-11500/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-10500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-12000
# Configuration saved in abc/checkpoint-12000/config.json
# Model weights saved in abc/checkpoint-12000/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-12000/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-11000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-12500
# Configuration saved in abc/checkpoint-12500/config.json
# Model weights saved in abc/checkpoint-12500/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-12500/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-11500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-13000
# Configuration saved in abc/checkpoint-13000/config.json
# Model weights saved in abc/checkpoint-13000/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-13000/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-12000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-13500
# Configuration saved in abc/checkpoint-13500/config.json
# Model weights saved in abc/checkpoint-13500/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-13500/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-12500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-14000
# Configuration saved in abc/checkpoint-14000/config.json
# Model weights saved in abc/checkpoint-14000/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-14000/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-13000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
# Saving model checkpoint to abc/checkpoint-14500
# Configuration saved in abc/checkpoint-14500/config.json
# Model weights saved in abc/checkpoint-14500/pytorch_model.bin
# Feature extractor saved in abc/checkpoint-14500/preprocessor_config.json
# Deleting older checkpoint [abc/checkpoint-13500] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=14940, training_loss=0.23672345734663916, metrics={'train_runtime': 6824.1305, 'train_samples_per_second': 17.488, 'train_steps_per_second': 2.189, 'total_flos': 3.0766610595969556e+18, 'train_loss': 0.23672345734663916, 'epoch': 30.0})

# %%
def map_to_result(batch):
  with torch.no_grad():
    input_values = torch.tensor(batch["input_values"], device="cuda").unsqueeze(0)
    logits = model(input_values).logits

  pred_ids = torch.argmax(logits, dim=-1)
  batch["pred_str"] = processor.batch_decode(pred_ids)[0]
  batch["text"] = processor.decode(batch["labels"], group_tokens=False)
  
  return batch

# %%
results = timit["test"].map(map_to_result, remove_columns=timit["test"].column_names)
# Out:
# 0ex [00:00, ?ex/s]
# /usr/local/lib/python3.7/dist-packages/torch/utils/checkpoint.py:25: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")

# %%
print("Test WER: {:.3f}".format(wer_metric.compute(predictions=results["pred_str"], references=results["text"])))
# Out:
# Test WER: 0.284

# %%
import torch

# %%
random_inp_tokens = torch.randint(0, 100, (1,2))
    random_output_tokens = torch.randint(0,100,(1,2))
    src_length = torch.from_numpy(np.asarray([1,2])).long()
