# %%
! pip3 install SpeechRecognition pydub
# Out:
# Requirement already satisfied: SpeechRecognition in c:\users\user\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: pydub in c:\users\user\anaconda3\lib\site-packages (0.25.1)

# %%
# importing libraries 
import speech_recognition as sr 
import os 
from pydub import AudioSegment
from pydub.silence import split_on_silence


# create a speech recognition object
r = sr.Recognizer()

# a function that splits the audio file into chunks
# and applies speech recognition
def get_large_audio_transcription(path):
    """
    Splitting the large audio file into chunks
    and apply speech recognition on each of these chunks
    """
    # open the audio file using pydub
    sound = AudioSegment.from_wav(path)  
    # split audio sound where silence is 700 miliseconds or more and get chunks
    chunks = split_on_silence(sound,
        # experiment with this value for your target audio file
        min_silence_len = 500,
        # adjust this per requirement
        silence_thresh = sound.dBFS-14,
        # keep the silence for 1 second, adjustable as well
        keep_silence=500,
    )
    folder_name = "audio-chunks"
    # create a directory to store the audio chunks
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    # process each chunk 
    for i, audio_chunk in enumerate(chunks, start=1):
        # export audio chunk and save it in
        # the `folder_name` directory.
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        # recognize the chunk
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text
    # return the text for all chunks detected
    return whole_text

path = "data.wav"
print("\nFull text:", get_large_audio_transcription(path))
# Out:
# audio-chunks\chunk1.wav : Penetrating looking at them coming and breaking the two major groups in the first being.
# audio-chunks\chunk2.wav : This question adaptation.
# audio-chunks\chunk3.wav : How do you respond right here in when going to the kind impacts.
# audio-chunks\chunk4.wav : Yad amazing team that clear is people on the move this question station to mitigation.
# audio-chunks\chunk5.wav : Aage main uske on size of impacts and expecting.
# Error:
# audio-chunks\chunk7.wav : Some many people are interested in moving at what we do to prevent this.
# audio-chunks\chunk8.wav : What start with the adaptations aaj.
# audio-chunks\chunk9.wav : And there are stronger than the way i would say this but that is why.
# audio-chunks\chunk10.wav : Next match wi vs ind.
# audio-chunks\chunk11.wav : My quest with given the silver rising rate of storm surges now it's back to the future.
# audio-chunks\chunk12.wav : How should be weight thanking coastal zoning policy.
# audio-chunks\chunk13.wav : Adp portal.
# audio-chunks\chunk14.wav : Can we ban zone of ozone hole over building in forest.
# audio-chunks\chunk15.wav : Aam.
# audio-chunks\chunk16.wav : Alfaaz on the shore destroyed by the terrorist league of the website cost in this issue.
# audio-chunks\chunk17.wav : Clearly these are some very critical question.
# audio-chunks\chunk18.wav : Amazon easy.
# audio-chunks\chunk19.wav : Flywheel.
# audio-chunks\chunk20.wav : Astrology.
# audio-chunks\chunk21.wav : Nss.
# audio-chunks\chunk22.wav : Beautiful sister.
# audio-chunks\chunk23.wav : Naagin 9 prasad.
# audio-chunks\chunk24.wav : But then khan these moments when sunvaee this place is love in cherish and have long standing.
# audio-chunks\chunk25.wav : A profession is taken.
# audio-chunks\chunk26.wav : Aasan nahi yahan.
# audio-chunks\chunk27.wav : Anand vihar to respond incredible copper and as you said before with all the nest mata install underwear.
# audio-chunks\chunk28.wav : Strawberry.
# audio-chunks\chunk29.wav : How do we eat crab with stand.
# audio-chunks\chunk30.wav : Staff society thanks.
# Error:
# audio-chunks\chunk32.wav : Stone house for the stone setting is built for it.
# audio-chunks\chunk33.wav : Voice investors in the retail twice over that substantial renovations twice and it going again and will therefore in a sense of insurance returns that cells as a month ago when i was in m****** for a similar event 1000 people who had not done that in their home because it's somewhat.
# audio-chunks\chunk34.wav : New sim a balanced and it's actually become a varied people getting back in their busy insurance process don't me.
# audio-chunks\chunk35.wav : Fastrack showroom rebuilding a home after a different sentences to some extent if it's not about you doing standard the weather will be son.
# audio-chunks\chunk36.wav : After the storm.
# audio-chunks\chunk37.wav : I am give you a million barriers and thoughts.
# audio-chunks\chunk38.wav : Awara back to the social and psychological love the shoreline is the identity of this state in our ways but.
# audio-chunks\chunk39.wav : 1 hour system of local taxation.
# audio-chunks\chunk40.wav : Is a policy change because expensive properties and.
# audio-chunks\chunk41.wav : The shoreline and america war mani 4 minutes.
# audio-chunks\chunk42.wav : And that anyone else to go for town other than the property tax in building no ability to regionally in this state.
# audio-chunks\chunk43.wav : So as to make a deal with me or further review and more restricted zoning and you show line i am in your views on the property tax revenue associated with big expensive homes around those who make up for that by giving you will be the revenue that comes from new factory catholic added in lens account in state that i am left with any incentive structure to do restricted zone because that's where the bread is is but many school download invoice you have home there so with that i was david conversation not simply a back.
# audio-chunks\chunk44.wav : When is mining by the way in which we can hack speakers we do a better job sharing tax revenues and then the blood pressure on the musical is the continuous build and rebuild the revolving restaurant.
# audio-chunks\chunk45.wav : I want to work in any small hands in.
# audio-chunks\chunk46.wav : Advising centre for 30% of their attacks.
# audio-chunks\chunk47.wav : Mela film.
# audio-chunks\chunk48.wav : Disha world.
# audio-chunks\chunk49.wav : Origin of 740.
# audio-chunks\chunk50.wav : Houses on invitations in on whether they are in the ratio becomes less and some.
# Error:
# Error:
# audio-chunks\chunk53.wav : Image read in an excel.
# audio-chunks\chunk54.wav : The power.
# audio-chunks\chunk55.wav : Smart test.
# audio-chunks\chunk56.wav : Types of tree.
# audio-chunks\chunk57.wav : How many patients on the town was not mention the instruction on the tourist.
# audio-chunks\chunk58.wav : Much bigger the all the making.
# Error:
# Error:
# audio-chunks\chunk61.wav : Freedom.
# audio-chunks\chunk62.wav : Opportunity to 6:30 training on we started to vacate.
# audio-chunks\chunk63.wav : Ways of connecting words are there is mein bf.
# audio-chunks\chunk64.wav : Small between bypass.
# audio-chunks\chunk65.wav : I am 70 your food.
# audio-chunks\chunk66.wav : Everything has a sakta you are metal industries located bye-bye.
# audio-chunks\chunk67.wav : It was thinking about how are you my favourite roadways.
# audio-chunks\chunk68.wav : Where do you locate a minute of your folder.
# audio-chunks\chunk69.wav : That have another folder.
# audio-chunks\chunk70.wav : Shizuka.
# audio-chunks\chunk71.wav : What is negotiation.
# Error:
# audio-chunks\chunk73.wav : Payal complex.
# audio-chunks\chunk74.wav : If we remove this slot homeowners o3 a situation with their property value.
# audio-chunks\chunk75.wav : When you will use funding that going in the schools in supporting your children.
# audio-chunks\chunk76.wav : Service.
# Error:
# Error:
# Error:
# audio-chunks\chunk80.wav : Quantify the number of subsidizing.
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# audio-chunks\chunk87.wav : Is going to have you.
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# audio-chunks\chunk94.wav : Lights out.
# Error:
# audio-chunks\chunk96.wav : People want to say bad how the policy environment.
# audio-chunks\chunk97.wav : Change pickup.
# audio-chunks\chunk98.wav : Making it happen that every lover.
# Error:
# audio-chunks\chunk100.wav : We are the end here to use the word the legacy of the governance systems.
# audio-chunks\chunk101.wav : And this is making.
# audio-chunks\chunk102.wav : Songs bhojpuri.
# audio-chunks\chunk103.wav : About many hundred.
# Error:
# audio-chunks\chunk105.wav : How does need to change the help.
# audio-chunks\chunk106.wav : Keep my 1000.
# Error:
# audio-chunks\chunk108.wav : Match india assurance.
# Error:
# audio-chunks\chunk110.wav : Is a text.
# Error:
# audio-chunks\chunk112.wav : Robbery sing many major insurance apollo out of the state of florida.
# Error:
# audio-chunks\chunk114.wav : Pawan.
# audio-chunks\chunk115.wav : Government steps in sas.
# Error:
# audio-chunks\chunk117.wav : And that sound good indian.
# audio-chunks\chunk118.wav : Then comes the next major hurricane in fort.
# audio-chunks\chunk119.wav : And take a folder in all the characters of odd and even.
# audio-chunks\chunk120.wav : Same kind wishes i am sure.
# audio-chunks\chunk121.wav : Hero no 1.
# Error:
# audio-chunks\chunk123.wav : Squares.
# Error:
# audio-chunks\chunk125.wav : Where is making people that don't want to show line understand.
# audio-chunks\chunk126.wav : All these discussions affect them because they are paining.
# audio-chunks\chunk127.wav : That what insurance it is cheaper because that subsidy over the remediation asta be done over the sea wall has to be rebuilt and i needed this panel oriya dichotomy of computation in connecticut i'd probably magic exist the rest of the country in which.
# audio-chunks\chunk128.wav : People that live in one.
# audio-chunks\chunk129.wav : Just don't think that this is a fax them and you do not want to set up a situation in which you get in 1 home order is against the.
# audio-chunks\chunk130.wav : Show my home 2 actor.
# audio-chunks\chunk131.wav : Do you have to have a people step in and and and for speakers.
# audio-chunks\chunk132.wav : There is a powerful consistency and every.
# audio-chunks\chunk133.wav : Attention to any person.
# audio-chunks\chunk134.wav : Any push back coming from those subsidizing that living in rebuilding and remediation then there is a difficult rapper lyrics.
# audio-chunks\chunk135.wav : $1 myself open for wonderful status in terms its.
# audio-chunks\chunk136.wav : Cosco park 7 acid sugar is on.
# audio-chunks\chunk137.wav : There is no remote.
# audio-chunks\chunk138.wav : Violet line.
# audio-chunks\chunk139.wav : Snake in the future this morning but the have resolved.
# audio-chunks\chunk140.wav : Open interest of public access.
# audio-chunks\chunk141.wav : Because my love will be abroad benefit.
# Error:
# audio-chunks\chunk143.wav : I am from massachusetts so i think i should say something about.
# audio-chunks\chunk144.wav : Disaster.
# audio-chunks\chunk145.wav : Improve on sunrise florida.
# Error:
# audio-chunks\chunk147.wav : How old is the warmer cost.
# audio-chunks\chunk148.wav : Agitated for the state to ca.
# audio-chunks\chunk149.wav : Fire insurance.
# audio-chunks\chunk150.wav : Preceded.
# audio-chunks\chunk151.wav : Cal subah exodus from kay karte marathi sriniet.
# audio-chunks\chunk152.wav : Insurance within 2 months property prices.
# audio-chunks\chunk153.wav : Notice system in ancient companies and their policies will be renewed.
# Error:
# audio-chunks\chunk155.wav : Which is always.
# Error:
# audio-chunks\chunk157.wav : Noida in the state coming in with.
# audio-chunks\chunk158.wav : I want to share plan.
# audio-chunks\chunk159.wav : Which is the massive subjugation of.
# audio-chunks\chunk160.wav : Quality people in beach.
# audio-chunks\chunk161.wav : Buy watch for free people.
# audio-chunks\chunk162.wav : Cancel the rule the problem and i agree with this and other is it ok to help insurance tpa messages.
# audio-chunks\chunk163.wav : Is that we have a lot of people in world.
# audio-chunks\chunk164.wav : Subsidizing risk on the cost and keep doing means it ok to where you can i keep having a problem.
# audio-chunks\chunk165.wav : Thanks for the core.
# audio-chunks\chunk166.wav : Sweets.
# audio-chunks\chunk167.wav : Se.
# audio-chunks\chunk168.wav : Thank you said for national flag.
# audio-chunks\chunk169.wav : Program.
# audio-chunks\chunk170.wav : Premium saurav affect breast.
# audio-chunks\chunk171.wav : People want to build in a dangerous place.
# audio-chunks\chunk172.wav : How to make a ravan of paper that.
# audio-chunks\chunk173.wav : Shubham.
# audio-chunks\chunk174.wav : One significant figures.
# audio-chunks\chunk175.wav : And i started this conversation so i am unconditional my my myself here.
# audio-chunks\chunk176.wav : Talking about this big house is it sit on the shore.
# audio-chunks\chunk177.wav : Barish what maps move coronavirus.
# audio-chunks\chunk178.wav : Embroidery job work experience of working in some records of cities like tempered in bridgeport.
# audio-chunks\chunk179.wav : Wooden videoing with coronavirus that include all along the neighborhood as well.
# audio-chunks\chunk180.wav : Insert one is the carrier speaker for that is that.
# audio-chunks\chunk181.wav : Should you shift the rest answer the homeowners over the rainbow.
# audio-chunks\chunk182.wav : You can get others.
# audio-chunks\chunk183.wav : Ramayan ramayan.
# audio-chunks\chunk184.wav : Get a wearable income properties in bridgeport in same field in norwalk is 12 the fact is we have an enormously high percentage.
# audio-chunks\chunk185.wav : Income individuals and families living with another our development parents work and sell this because it makes sense that start with a.
# audio-chunks\chunk186.wav : Devang kerala state housing board online in use can be careful that who has the prices.
# audio-chunks\chunk187.wav : Internet.
